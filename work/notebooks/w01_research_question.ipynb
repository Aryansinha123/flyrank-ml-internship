# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I chose the Refresh / Content Opportunity Scoring lane.
#
# The goal is to identify webpages that should be reviewed for content updates. Instead of reviewing every page manually, a machine learning model can rank pages according to their likelihood of needing a refresh.
#
# I chose this lane because it has a clear business value. SEO teams usually have limited time, so ranking the most important pages first can help improve search performance efficiently.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision:
# Which webpages should be reviewed first for content refresh?
#
# Unit of Analysis:
# One webpage
#
# Output:
# A ranked list of webpages that are likely need to be updated.
#
# Action:
# An SEO specialist reviews the highest-ranked pages and updates their content
#
# Cost of a Wrong Recommendation:
#
# False Positive:
# Time is wasted reviewing a page that did not actually need updating.
#
# False Negative:
# A page that needed updating is ignored and may lose search traffic.
#
# Why Machine Learning?
#
# Many factors affect search performance. Machine learning can analyze these factors together and help prioritize pages better than using simple manual rules.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ## 3. Quick Look at the Data
#
# The starter dataset contains **30,000 webpages** and **44 features**, providing a large amount of information for analysis.
#
# The average number of impressions over the last 90 days is **5,200.37**, which shows that many pages have measurable search visibility.
#
# The average number of sessions over the last 90 days is **37.07**, indicating that user engagement data is available for each page.
#
# The dataset also contains **16,262 pages** with a **"down"** trend direction. Since my chosen lane focuses on identifying pages that should be reviewed for content refresh, this suggests there are many potential candidates for ranking and prioritization.
#
# These observations indicate that the dataset contains enough information to build and evaluate a decision-support system for content refresh recommendations.

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
print("Dataset Shape:", df.shape)

print("Average Impressions (90d):", df["impressions_90d"].mean())

print("Average Sessions (90d):", df["sessions_90d"].mean())

print("\nTrend Direction Counts:")
print(df["trend_direction"].value_counts())
# Out:
# Dataset Shape: (30000, 44)
# Average Impressions (90d): 5200.3663
# Average Sessions (90d): 37.066633333333336
#
# Trend Direction Counts:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project can identify patterns associated with pages that may need a content refresh.
#
# The model provides decision support and helps prioritize pages for review.
#
# However, it cannot prove that updating a page will improve Google rankings. Search performance depends on many external factors that are not captured in the dataset.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
